# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=169, step=1)

# %%
df.index = [0]*169

# %%
df
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 0         60    117       145     479.0
# 0         60    103       135     340.0
# 0         45    109       175     282.4
# 0         45    117       148     406.0
# ..       ...    ...       ...       ...
# 0         60    105       140     290.8
# 0         60    110       145     300.0
# 0         60    115       145     310.2
# 0         75    120       150     320.4
# 0         75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.index = range(1, 170, 1)

# %%
df.reset_index()
# Out:
#      index  Duration  Pulse  Maxpulse  Calories
# 0        1        60    110       130     409.1
# 1        2        60    117       145     479.0
# 2        3        60    103       135     340.0
# 3        4        45    109       175     282.4
# 4        5        45    117       148     406.0
# ..     ...       ...    ...       ...       ...
# 164    165        60    105       140     290.8
# 165    166        60    110       145     300.0
# 166    167        60    115       145     310.2
# 167    168        75    120       150     320.4
# 168    169        75    125       150     330.4
#
# [169 rows x 5 columns]

# %%
df.reset_index(drop=False)
# Out:
#      index  Duration  Pulse  Maxpulse  Calories
# 0        1        60    110       130     409.1
# 1        2        60    117       145     479.0
# 2        3        60    103       135     340.0
# 3        4        45    109       175     282.4
# 4        5        45    117       148     406.0
# ..     ...       ...    ...       ...       ...
# 164    165        60    105       140     290.8
# 165    166        60    110       145     300.0
# 166    167        60    115       145     310.2
# 167    168        75    120       150     320.4
# 168    169        75    125       150     330.4
#
# [169 rows x 5 columns]

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 1          60    110       130     409.1
# 2          60    117       145     479.0
# 3          60    103       135     340.0
# 4          45    109       175     282.4
# 5          45    117       148     406.0
# ..        ...    ...       ...       ...
# 165        60    105       140     290.8
# 166        60    110       145     300.0
# 167        60    115       145     310.2
# 168        75    120       150     320.4
# 169        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.set_index("Duration")
# Out:
#           Pulse  Maxpulse  Calories
# Duration
# 60          110       130     409.1
# 60          117       145     479.0
# 60          103       135     340.0
# 45          109       175     282.4
# 45          117       148     406.0
# ...         ...       ...       ...
# 60          105       140     290.8
# 60          110       145     300.0
# 60          115       145     310.2
# 75          120       150     320.4
# 75          125       150     330.4
#
# [169 rows x 3 columns]

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 1          60    110       130     409.1
# 2          60    117       145     479.0
# 3          60    103       135     340.0
# 4          45    109       175     282.4
# 5          45    117       148     406.0
# ..        ...    ...       ...       ...
# 165        60    105       140     290.8
# 166        60    110       145     300.0
# 167        60    115       145     310.2
# 168        75    120       150     320.4
# 169        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
country = ["Brazil", "Russia", "India", "China", "South Africa"]
capital = ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"]
area = [8.516, 17.10, 3.286, 9.67, 2.98]
population = [200.4, 143.5, 1252, 133, 4.3] 

brics = pd.DataFrame(data={'country': country, 
                  'capital': capital,
                  'area': area,
                  'population': population})
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics.rename(columns = {"country" : "Countries", "area" : "Area"} , inplace=True)
brics.rename(index={3:"Nothing"})
# Out:
#             Countries    capital    Area  population
# 0              Brazil   Brasilia   8.516       200.4
# 1              Russia     Moscow  17.100       143.5
# 2               India  New Delhi   3.286      1252.0
# Nothing         China    Beijing   9.670       133.0
# 4        South Africa   Pretoria   2.980         4.3

# %%
brics
# Out:
#       Countries    capital    Area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics.drop(labels=[0, 1], axis=0)
# Out:
#       Countries    capital   Area  population
# 2         India  New Delhi  3.286      1252.0
# 3         China    Beijing  9.670       133.0
# 4  South Africa   Pretoria  2.980         4.3

# %%
df1 = pd.read_excel("sales.xlsx")

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        60    110       130     409.1
# 2        60    117       145     479.0
# 3        60    103       135     340.0
# 4        45    109       175     282.4
# 5        45    117       148     406.0

# %%
df.plot(kind="scatter", x = "Maxpulse", y = "Pulse")
plt.title("Duration vs Pulse")
# Out:
# Text(0.5, 1.0, 'Duration vs Pulse')

# %%
df["Pulse"].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
brics
# Out:
#       Countries    capital    Area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
# plt.style.
brics.plot(kind="bar", x = "Countries", y = "Area")
# Out:
# <Axes: xlabel='Countries'>

# %%
df2 = pd.DataFrame({
   "Car": ['BMW', 'Lexus', 'Tesla', 'Mustang', 'Mercedes', 'Jaguar'],
    "Reg_Price": [7000, 1500, 5000, 8000, 9000, 6000]
})
df2
# Out:
#         Car  Reg_Price
# 0       BMW       7000
# 1     Lexus       1500
# 2     Tesla       5000
# 3   Mustang       8000
# 4  Mercedes       9000
# 5    Jaguar       6000

# %%
df2.plot(kind="pie" , x = "Car", y = "Reg_Price")
# Out:
# <Axes: ylabel='Reg_Price'>

# %%
s1 = pd.Series(np.arange(1, 5), index=['a', 'b', 'c','d']) 
s2 = pd.Series(np.arange(1, 10, 2), index=['a', 'b', 'c', 'd', 'e'])
print(f"{s1}\n{s2}")
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int32
# a    1
# b    3
# c    5
# d    7
# e    9
# dtype: int32

# %%
s1-s2
# Out:
# a    0.0
# b   -1.0
# c   -2.0
# d   -3.0
# e    NaN
# dtype: float64

# %%
type(np.nan)
# Out:
# float

# %%
type(pd.NA)
# Out:
# pandas._libs.missing.NAType

# %%
df3 = pd.read_csv("sample2.csv")

# %%
df3
# Out:
#     Roll No. Section Branch  Physics  Chemistry  Maths  Computer         DOB
# 0          1       A     CS     56.0       57.0   58.0      59.0  01-01-2001
# 1          2       A    ECE     23.0       24.0   25.0      26.0  02-01-2001
# 2          3       B   MECH     89.0       25.0   26.0      27.0  03-01-2001
# 3          4       C   MECH     45.0       26.0   27.0      28.0  04-01-2001
# 4          5       A     CS     23.0       27.0   28.0      29.0  05-01-2001
# 5          6       A    ECE     90.0        NaN   29.0      30.0  06-01-2001
# 6          7       B     CS     12.0       13.0   14.0      15.0  07-01-2001
# 7          8       C    NaN     78.0       14.0   15.0      16.0  08-01-2001
# 8          9       A    ECE      NaN       15.0   16.0      17.0  09-01-2001
# 9         10       A     CS     45.0       16.0   17.0      18.0  10-01-2001
# 10        11       B    ECE      NaN       17.0   18.0      19.0  11-01-2001
# ...

# %%
df3.isnull()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Roll No.   30 non-null     int64
#  1   Section    30 non-null     object
#  2   Branch     28 non-null     object
#  3   Physics    27 non-null     float64
#  4   Chemistry  26 non-null     float64
#  5   Maths      28 non-null     float64
#  6   Computer   29 non-null     float64
#  7   DOB        30 non-null     object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 2.0+ KB

# %%
df3["Section"].count()
# Out:
# 30

# %%
df3["Chemistry"].count()
# Out:
# 26

# %%
df3["Maths"].isnull().sum()
# Out:
# 2

# %%
df3.notnull()
# Out:
#     Roll No.  Section  Branch  Physics  Chemistry  Maths  Computer   DOB
# 0       True     True    True     True       True   True      True  True
# 1       True     True    True     True       True   True      True  True
# 2       True     True    True     True       True   True      True  True
# 3       True     True    True     True       True   True      True  True
# 4       True     True    True     True       True   True      True  True
# 5       True     True    True     True      False   True      True  True
# 6       True     True    True     True       True   True      True  True
# 7       True     True   False     True       True   True      True  True
# 8       True     True    True    False       True   True      True  True
# 9       True     True    True     True       True   True      True  True
# 10      True     True    True    False       True   True      True  True
# 11      True     True    True     True      False   True      True  True
# ...

# %%
df3.dropna(axis=1)
# Out:
#     Roll No. Section         DOB
# 0          1       A  01-01-2001
# 1          2       A  02-01-2001
# 2          3       B  03-01-2001
# 3          4       C  04-01-2001
# 4          5       A  05-01-2001
# 5          6       A  06-01-2001
# 6          7       B  07-01-2001
# 7          8       C  08-01-2001
# 8          9       A  09-01-2001
# 9         10       A  10-01-2001
# 10        11       B  11-01-2001
# 11        12       C  12-01-2001
# 12        13       A  13-01-2001
# 13        14       A  14-01-2001
# 14        15       B  15-01-2001
# 15        16       C  16-01-2001
# 16        17       A  17-01-2001
# 17        18       A  18-01-2001
# 18        19       B  19-01-2001
# 19        20       C  20-01-2001
# 20        21       A  21-01-2001
# 21        22       A  22-01-2001
# 22        23       B  23-01-2001
# 23        24       C  24-01-2001
# 24        25       A  25-01-2001
# 25        26       A  26-01-2001
# 26        27       B  27-01-2001
# ...

# %%
df3.dropna(axis=0, how = "all")
# Out:
#     Roll No. Section Branch  Physics  Chemistry  Maths  Computer         DOB
# 0          1       A     CS     56.0       57.0   58.0      59.0  01-01-2001
# 1          2       A    ECE     23.0       24.0   25.0      26.0  02-01-2001
# 2          3       B   MECH     89.0       25.0   26.0      27.0  03-01-2001
# 3          4       C   MECH     45.0       26.0   27.0      28.0  04-01-2001
# 4          5       A     CS     23.0       27.0   28.0      29.0  05-01-2001
# 5          6       A    ECE     90.0        NaN   29.0      30.0  06-01-2001
# 6          7       B     CS     12.0       13.0   14.0      15.0  07-01-2001
# 7          8       C    NaN     78.0       14.0   15.0      16.0  08-01-2001
# 8          9       A    ECE      NaN       15.0   16.0      17.0  09-01-2001
# 9         10       A     CS     45.0       16.0   17.0      18.0  10-01-2001
# 10        11       B    ECE      NaN       17.0   18.0      19.0  11-01-2001
# ...

# %%
df3.fillna(value=0, axis=0)
# Out:
#     Roll No. Section Branch  Physics  Chemistry  Maths  Computer         DOB
# 0          1       A     CS     56.0       57.0   58.0      59.0  01-01-2001
# 1          2       A    ECE     23.0       24.0   25.0      26.0  02-01-2001
# 2          3       B   MECH     89.0       25.0   26.0      27.0  03-01-2001
# 3          4       C   MECH     45.0       26.0   27.0      28.0  04-01-2001
# 4          5       A     CS     23.0       27.0   28.0      29.0  05-01-2001
# 5          6       A    ECE     90.0        0.0   29.0      30.0  06-01-2001
# 6          7       B     CS     12.0       13.0   14.0      15.0  07-01-2001
# 7          8       C      0     78.0       14.0   15.0      16.0  08-01-2001
# 8          9       A    ECE      0.0       15.0   16.0      17.0  09-01-2001
# 9         10       A     CS     45.0       16.0   17.0      18.0  10-01-2001
# 10        11       B    ECE      0.0       17.0   18.0      19.0  11-01-2001
# ...

# %%
df3.fillna({ "Physics":0 , "Chemistry" : 19, "Computer":20, "Maths" : df3["Maths"].mode()})
# Out:
#     Roll No. Section Branch  Physics  Chemistry  Maths  Computer         DOB
# 0          1       A     CS     56.0       57.0   58.0      59.0  01-01-2001
# 1          2       A    ECE     23.0       24.0   25.0      26.0  02-01-2001
# 2          3       B   MECH     89.0       25.0   26.0      27.0  03-01-2001
# 3          4       C   MECH     45.0       26.0   27.0      28.0  04-01-2001
# 4          5       A     CS     23.0       27.0   28.0      29.0  05-01-2001
# 5          6       A    ECE     90.0       19.0   29.0      30.0  06-01-2001
# 6          7       B     CS     12.0       13.0   14.0      15.0  07-01-2001
# 7          8       C    NaN     78.0       14.0   15.0      16.0  08-01-2001
# 8          9       A    ECE      0.0       15.0   16.0      17.0  09-01-2001
# 9         10       A     CS     45.0       16.0   17.0      18.0  10-01-2001
# 10        11       B    ECE      0.0       17.0   18.0      19.0  11-01-2001
# ...

# %%
df3.fillna(method='bfill')
# Out:
#     Roll No. Section Branch  Physics  Chemistry  Maths  Computer         DOB
# 0          1       A     CS     56.0       57.0   58.0      59.0  01-01-2001
# 1          2       A    ECE     23.0       24.0   25.0      26.0  02-01-2001
# 2          3       B   MECH     89.0       25.0   26.0      27.0  03-01-2001
# 3          4       C   MECH     45.0       26.0   27.0      28.0  04-01-2001
# 4          5       A     CS     23.0       27.0   28.0      29.0  05-01-2001
# 5          6       A    ECE     90.0       13.0   29.0      30.0  06-01-2001
# 6          7       B     CS     12.0       13.0   14.0      15.0  07-01-2001
# 7          8       C    ECE     78.0       14.0   15.0      16.0  08-01-2001
# 8          9       A    ECE     45.0       15.0   16.0      17.0  09-01-2001
# 9         10       A     CS     45.0       16.0   17.0      18.0  10-01-2001
# 10        11       B    ECE     88.0       17.0   18.0      19.0  11-01-2001
# ...

# %%
df3
# Out:
#     Roll No. Section Branch  Physics  Chemistry  Maths  Computer         DOB
# 0          1       A     CS     56.0       57.0   58.0      59.0  01-01-2001
# 1          2       A    ECE     23.0       24.0   25.0      26.0  02-01-2001
# 2          3       B   MECH     89.0       25.0   26.0      27.0  03-01-2001
# 3          4       C   MECH     45.0       26.0   27.0      28.0  04-01-2001
# 4          5       A     CS     23.0       27.0   28.0      29.0  05-01-2001
# 5          6       A    ECE     90.0        NaN   29.0      30.0  06-01-2001
# 6          7       B     CS     12.0       13.0   14.0      15.0  07-01-2001
# 7          8       C    NaN     78.0       14.0   15.0      16.0  08-01-2001
# 8          9       A    ECE      NaN       15.0   16.0      17.0  09-01-2001
# 9         10       A     CS     45.0       16.0   17.0      18.0  10-01-2001
# 10        11       B    ECE      NaN       17.0   18.0      19.0  11-01-2001
# ...

# %%
df1
# Out:
#     Region     Phone  Sales
# 0     East     Nokia    100
# 1     East  Motorola    300
# 2     East   Samsung    400
# 3     East   Kyocera    450
# 4     West     Nokia     90
# 5     West  Motorola    110
# 6     West   Samsung    150
# 7     West   Kyocera    190
# 8    South     Nokia    200
# 9    South  Motorola    220
# 10   South   Samsung    230
# 11   South   Kyocera    250
# 12   North     Nokia    270
# 13   North  Motorola    290
# 14   North   Samsung    310
# 15   North   Kyocera    350
# 16  Canada     Nokia    100
# 17  Canada  Motorola     90
# 18  Canada   Samsung     50
# 19  Canada   Kyocera     75

# %%
df1.replace(to_replace = "Nokia", value= "OnePlus", )
# Out:
#     Region     Phone  Sales
# 0     East   OnePlus    100
# 1     East  Motorola    300
# 2     East   Samsung    400
# 3     East   Kyocera    450
# 4     West   OnePlus     90
# 5     West  Motorola    110
# 6     West   Samsung    150
# 7     West   Kyocera    190
# 8    South   OnePlus    200
# 9    South  Motorola    220
# 10   South   Samsung    230
# 11   South   Kyocera    250
# 12   North   OnePlus    270
# 13   North  Motorola    290
# 14   North   Samsung    310
# 15   North   Kyocera    350
# 16  Canada   OnePlus    100
# 17  Canada  Motorola     90
# 18  Canada   Samsung     50
# 19  Canada   Kyocera     75

# %%
df1.replace(to_replace = ["East", "Motorola"], value = ["North_East", "Asus"])
# Out:
#         Region    Phone  Sales
# 0   North_East    Nokia    100
# 1   North_East     Asus    300
# 2   North_East  Samsung    400
# 3   North_East  Kyocera    450
# 4         West    Nokia     90
# 5         West     Asus    110
# 6         West  Samsung    150
# 7         West  Kyocera    190
# 8        South    Nokia    200
# 9        South     Asus    220
# 10       South  Samsung    230
# 11       South  Kyocera    250
# 12       North    Nokia    270
# 13       North     Asus    290
# 14       North  Samsung    310
# 15       North  Kyocera    350
# 16      Canada    Nokia    100
# 17      Canada     Asus     90
# 18      Canada  Samsung     50
# 19      Canada  Kyocera     75

# %%
df1
# Out:
#     Region     Phone  Sales
# 0     East     Nokia    100
# 1     East  Motorola    300
# 2     East   Samsung    400
# 3     East   Kyocera    450
# 4     West     Nokia     90
# 5     West  Motorola    110
# 6     West   Samsung    150
# 7     West   Kyocera    190
# 8    South     Nokia    200
# 9    South  Motorola    220
# 10   South   Samsung    230
# 11   South   Kyocera    250
# 12   North     Nokia    270
# 13   North  Motorola    290
# 14   North   Samsung    310
# 15   North   Kyocera    350
# 16  Canada     Nokia    100
# 17  Canada  Motorola     90
# 18  Canada   Samsung     50
# 19  Canada   Kyocera     75

# %%
df1 = df1["Sales"].replace([100, 300, 230, 290], ['A', 'B', 'C', 'D'])

# %%
df1.replace('[A-Za-z]', 120, regex=True)
# Out:
# 0     120
# 1     120
# 2     400
# 3     450
# 4      90
# 5     110
# 6     150
# 7     190
# 8     200
# 9     220
# 10    120
# 11    250
# 12    270
# 13    120
# 14    310
# 15    350
# 16    120
# 17     90
# 18     50
# 19     75
# Name: Sales, dtype: int64

# %%
brics
# Out:
#       Countries    capital    Area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics.replace("China", method="ffill")
# Out:
#       Countries    capital    Area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         India    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics.index = range(1,6)

# %%
brics
# Out:
#       Countries    capital    Area  population
# 1        Brazil   Brasilia   8.516       200.4
# 2        Russia     Moscow  17.100       143.5
# 3         India  New Delhi   3.286      1252.0
# 4         China    Beijing   9.670       133.0
# 5  South Africa   Pretoria   2.980         4.3

# %%
df.index = range(1, 170)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 1          60    110       130     409.1
# 2          60    117       145     479.0
# 3          60    103       135     340.0
# 4          45    109       175     282.4
# 5          45    117       148     406.0
# ..        ...    ...       ...       ...
# 165        60    105       140     290.8
# 166        60    110       145     300.0
# 167        60    115       145     310.2
# 168        75    120       150     320.4
# 169        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.loc[45:123 , "Duration" : "Calories"]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 45         60    111       131     397.0
# 46         60     99       119     273.0
# 47         60    109       153     387.6
# 48         45    111       136     300.0
# 49         45    108       129     298.0
# ..        ...    ...       ...       ...
# 119        60    105       125       NaN
# 120        60    103       124     332.7
# 121        30    112       137     193.9
# 122        45    100       120     100.7
# 123        60    119       169     336.7
#
# [79 rows x 4 columns]

# %%
brics.index = ['a', 'b', 'c', 'd', 'e']

# %%
brics
# Out:
#       Countries    capital    Area  population
# a        Brazil   Brasilia   8.516       200.4
# b        Russia     Moscow  17.100       143.5
# c         India  New Delhi   3.286      1252.0
# d         China    Beijing   9.670       133.0
# e  South Africa   Pretoria   2.980         4.3

# %%
brics.loc["b":"d"]
# Out:
#   Countries    capital    Area  population
# b    Russia     Moscow  17.100       143.5
# c     India  New Delhi   3.286      1252.0
# d     China    Beijing   9.670       133.0

# %%
brics.iloc[1:4]
# Out:
#   Countries    capital    Area  population
# b    Russia     Moscow  17.100       143.5
# c     India  New Delhi   3.286      1252.0
# d     China    Beijing   9.670       133.0

# %%
brics
# Out:
#       Countries    capital    Area  population
# a        Brazil   Brasilia   8.516       200.4
# b        Russia     Moscow  17.100       143.5
# c         India  New Delhi   3.286      1252.0
# d         China    Beijing   9.670       133.0
# e  South Africa   Pretoria   2.980         4.3

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 1          60    110       130     409.1
# 2          60    117       145     479.0
# 3          60    103       135     340.0
# 4          45    109       175     282.4
# 5          45    117       148     406.0
# ..        ...    ...       ...       ...
# 165        60    105       140     290.8
# 166        60    110       145     300.0
# 167        60    115       145     310.2
# 168        75    120       150     320.4
# 169        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df["Duration"].value_counts()
# Out:
# Duration
# 60     79
# 45     35
# 30     16
# 20      9
# 90      8
# 150     4
# 180     3
# 120     3
# 210     2
# 160     2
# 15      2
# 75      2
# 80      1
# 300     1
# 270     1
# 25      1
# Name: count, dtype: int64

# %%
df["Duration"].unique()
# Out:
# array([ 60,  45,  30,  80,  20, 210, 160, 180, 150, 300,  90, 120, 270,
#         15,  25,  75], dtype=int64)

# %%
df["Duration"]
# Out:
# 1      60
# 2      60
# 3      60
# 4      45
# 5      45
#        ..
# 165    60
# 166    60
# 167    60
# 168    75
# 169    75
# Name: Duration, Length: 169, dtype: int64

# %%
df[["Duration", "Pulse"]][df["Duration"] > 60]
# Out:
#      Duration  Pulse
# 52         80    123
# 61        210    108
# 62        160    110
# 63        160    109
# 66        180     90
# 67        150    105
# 68        150    107
# 70        300    108
# 71        150     97
# 73         90    100
# 74        150     97
# 76         90     98
# 79        120    100
# 80        270    100
# 84        120    100
# 88        120    100
# 91        180    101
# 100        90     93
# 102        90     90
# 103        90     90
# 104        90     90
# 107       180     90
# 109        90     90
# 110       210    137
# 129        90     99
# 168        75    120
# 169        75    125

# %%
df["Duration"].argmax()
# Out:
# 69

# %%
df3
# Out:
#     Roll No. Section Branch  Physics  Chemistry  Maths  Computer         DOB
# 0          1       A     CS     56.0       57.0   58.0      59.0  01-01-2001
# 1          2       A    ECE     23.0       24.0   25.0      26.0  02-01-2001
# 2          3       B   MECH     89.0       25.0   26.0      27.0  03-01-2001
# 3          4       C   MECH     45.0       26.0   27.0      28.0  04-01-2001
# 4          5       A     CS     23.0       27.0   28.0      29.0  05-01-2001
# 5          6       A    ECE     90.0        NaN   29.0      30.0  06-01-2001
# 6          7       B     CS     12.0       13.0   14.0      15.0  07-01-2001
# 7          8       C    NaN     78.0       14.0   15.0      16.0  08-01-2001
# 8          9       A    ECE      NaN       15.0   16.0      17.0  09-01-2001
# 9         10       A     CS     45.0       16.0   17.0      18.0  10-01-2001
# 10        11       B    ECE      NaN       17.0   18.0      19.0  11-01-2001
# ...

# %%
df3.groupby("Section")["Physics"].agg(["mean", "sum", "max", "min", "sem"])
# Out:
#               mean    sum   max   min        sem
# Section
# A        50.733333  761.0  90.0  22.0   5.198412
# B        50.800000  254.0  89.0  12.0  12.240915
# C        58.714286  411.0  88.0  44.0   6.549134
