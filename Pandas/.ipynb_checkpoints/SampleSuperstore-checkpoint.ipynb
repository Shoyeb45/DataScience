# %%
import pandas as pd

# %%
df1 = pd.read_excel("E:/Notes/DataScience/Pandas/SampleSuperstore.xlsx", sheet_name = "Orders")
# Out:
# C:\tools\Anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df2 = pd.read_excel("E:/Notes/DataScience/Pandas/SampleSuperstore.xlsx", sheet_name = "Returns")
# Out:
# C:\tools\Anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
print(df1.head())
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
print(df2.head())
# Out:
#   Returned        Order ID
# 0      Yes  CA-2016-100762
# 1      Yes  CA-2016-100762
# 2      Yes  CA-2016-100762
# 3      Yes  CA-2016-100762
# 4      Yes  CA-2016-100867

# %%
g = pd.merge(df1, df2, on = "Order ID", how = "left")
g.set_index("Row ID" , inplace = True)

# %%
l = g.columns

# %%
l
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country/Region', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Returned'],
#       dtype='object')

# %%
g
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 3       CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 4       US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 5       US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# ...                ...        ...        ...             ...         ...
# 9992    CA-2019-121258 2019-02-26 2019-03-03  Standard Class    DB-13060
# 9993    CA-2019-121258 2019-02-26 2019-03-03  Standard Class    DB-13060
# 9993    CA-2019-121258 2019-02-26 2019-03-03  Standard Class    DB-13060
# 9993    CA-2019-121258 2019-02-26 2019-03-03  Standard Class    DB-13060
# 9994    CA-2019-119914 2019-05-04 2019-05-09    Second Class    CC-12220
#
#           Customer Name    Segment Country/Region             City  \
# Row ID
# ...

# %%
# Assignment

# %%
abbre = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv')
areas= pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv')
pop = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv')

# %%
print(f"{abbre.head()}\n {abbre.info()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         51 non-null     object
#  1   abbreviation  51 non-null     object
# dtypes: object(2)
# memory usage: 948.0+ bytes
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA
#  None

# %%
print(f"{areas.head()}\n {areas.info()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   area (sq. mi)  52 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 964.0+ bytes
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707
#  None

# %%
pop.rename(columns={"state/region" : "abbreviation"} , inplace=True)
print(f"{pop.head()}\n {pop.info()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   abbreviation  2544 non-null   object
#  1   ages          2544 non-null   object
#  2   year          2544 non-null   int64
#  3   population    2524 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 79.6+ KB
#   abbreviation     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0
#  None

# %%
df1 = pd.merge(abbre, areas, on = "state")
df1
# Out:
#                    state abbreviation  area (sq. mi)
# 0                Alabama           AL          52423
# 1                 Alaska           AK         656425
# 2                Arizona           AZ         114006
# 3               Arkansas           AR          53182
# 4             California           CA         163707
# 5               Colorado           CO         104100
# 6            Connecticut           CT           5544
# 7               Delaware           DE           1954
# 8   District of Columbia           DC             68
# 9                Florida           FL          65758
# 10               Georgia           GA          59441
# 11                Hawaii           HI          10932
# 12                 Idaho           ID          83574
# 13              Illinois           IL          57918
# 14               Indiana           IN          36420
# 15                  Iowa           IA          56276
# 16                Kansas           KS          82282
# ...
