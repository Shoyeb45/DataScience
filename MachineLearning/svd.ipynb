# %%
import numpy as np

# %%
A = np.array([[3, 1], [1, 3]])

# %%
A
# Out:
# array([[3, 1],
#        [1, 3]])

# %%
U, S, V_t = np.linalg.svd(A)

# %%
U
# Out:
# array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
S
# Out:
# array([4., 2.])

# %%
V_t
# Out:
# array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
# Out:
# array([[False, False],
#        [False,  True]])
